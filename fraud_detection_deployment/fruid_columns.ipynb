# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\10acadamyAMIweek-8-9\data\merged_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  user_id          signup_time        purchase_time  \
# 0         634   247547  2015-06-28 03:00:34  2015-08-09 03:57:29
# 1         635   220737  2015-01-28 14:21:11  2015-02-11 20:28:28
# 2         636   390400  2015-03-19 20:49:09  2015-04-11 23:41:23
# 3         637    69592  2015-02-24 06:11:57  2015-05-23 16:40:14
# 4         638   174987  2015-07-07 12:58:11  2015-11-03 04:04:30
#
#    purchase_value      device_id  source browser sex  age  class    ip_int  \
# 0              47  KIXYSVCHIPQBR     SEO  Safari   F   30      0  16778864
# 1              15  PKYOWQKWGJNJI     SEO  Chrome   F   34      0  16842045
# 2              44  LVCSXLISZHVUO     Ads      IE   M   29      0  16843656
# 3              55  UHAUHNXXUADJE  Direct  Chrome   F   30      0  16938732
# 4              51  XPGPMOHIDRMGE     SEO  Chrome   F   37      0  16971984
#
#      country
# 0  Australia
# 1   Thailand
# 2      China
# 3      China
# 4   Thailand

# %%
# Select only the relevant columns
cleaned_data = df[[
    'purchase_time', 
    'purchase_value', 
    'device_id', 
    'source', 
    'browser', 
    'age', 
    'class', 
    'country'  # Include only if you want geographical insights
]]

# %%
# Save the cleaned data to a new CSV file
cleaned_data_path = r"C:\Users\Yibabe\Desktop\10acadamyAMIweek-8-9\data/cleaned_fraud_data.csv"  # Update the path as needed
cleaned_data.to_csv(cleaned_data_path, index=False)

print("Cleaned data saved successfully.")
# Out:
# Cleaned data saved successfully.

# %%
cleaned_data.head()
# Out:
#          purchase_time  purchase_value      device_id  source browser  age  \
# 0  2015-08-09 03:57:29              47  KIXYSVCHIPQBR     SEO  Safari   30
# 1  2015-02-11 20:28:28              15  PKYOWQKWGJNJI     SEO  Chrome   34
# 2  2015-04-11 23:41:23              44  LVCSXLISZHVUO     Ads      IE   29
# 3  2015-05-23 16:40:14              55  UHAUHNXXUADJE  Direct  Chrome   30
# 4  2015-11-03 04:04:30              51  XPGPMOHIDRMGE     SEO  Chrome   37
#
#    class    country
# 0      0  Australia
# 1      0   Thailand
# 2      0      China
# 3      0      China
# 4      0   Thailand

# %%
from dash import Dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
# Out:
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_3960\570857726.py:2: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\Yibabe\AppData\Local\Temp\ipykernel_3960\570857726.py:3: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
# !pip install dash plotly
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement plotly (from versions: none)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for plotly
# ...

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# ...
#   Using cached pip-24.3.1-py3-none-any.whl.metadata (3.7 kB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.5/1.8 MB 294.2 kB/s eta 0:00:05
#    ----------- ---------------------------- 0.5/1.8 MB 294.2 kB/s eta 0:00:05
# ...

# %%
# !pip install dash plotly
# Out:
# ...
#   Using cached dash-2.18.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.5 MB 2.1 MB/s eta 0:00:04
#    -------- ------------------------------- 1.6/7.5 MB 4.0 MB/s eta 0:00:02
#    ------------ --------------------------- 2.4/7.5 MB 3.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.5 MB 3.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.1/7.5 MB 3.9 MB/s eta 0:00:02
#    ------------------ --------------------- 3.4/7.5 MB 3.1 MB/s eta 0:00:02
#    ------------------- -------------------- 3.7/7.5 MB 2.8 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.5 MB 2.6 MB/s eta 0:00:02
#    --------------------- ------------------ 3.9/7.5 MB 2.6 MB/s eta 0:00:02
# ...
